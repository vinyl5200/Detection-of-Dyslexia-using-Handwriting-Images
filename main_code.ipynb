# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: abydos==0.5.0 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: azure-cognitiveservices-vision-computervision==0.9.0 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: language-tool-python==2.7.1 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: Pillow==9.2.0 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (9.2.0)
# Requirement already satisfied: textblob==0.17.1 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: streamlit==1.12.0 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (1.12.0)
# Requirement already satisfied: streamlit-lottie==0.0.3 in ./.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.0.3)
# Requirement already satisfied: numpy in ./.local/lib/python3.10/site-packages (from abydos==0.5.0->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: deprecation in ./.local/lib/python3.10/site-packages (from abydos==0.5.0->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: msrest>=0.5.0 in ./.local/lib/python3.10/site-packages (from azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in ./.local/lib/python3.10/site-packages (from azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (1.1.28)
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from language-tool-python==2.7.1->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tqdm in ./.local/lib/python3.10/site-packages (from language-tool-python==2.7.1->-r requirements.txt (line 3)) (4.66.2)
# Requirement already satisfied: nltk>=3.1 in ./.local/lib/python3.10/site-packages (from textblob==0.17.1->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: pympler>=0.9 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: pandas>=0.21.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (0.8.1b0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (4.10.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/lib/python3/dist-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (4.6.4)
# Requirement already satisfied: pyarrow>=4.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (15.0.2)
# Requirement already satisfied: rich>=10.11.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (13.7.1)
# Requirement already satisfied: gitpython!=3.1.19 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (3.1.43)
# Requirement already satisfied: validators>=0.2 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (0.24.0)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (8.0.3)
# Requirement already satisfied: python-dateutil in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: blinker>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (1.4)
# Requirement already satisfied: altair>=3.2.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: packaging>=14.1 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: protobuf<4,>=3.12 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: semver in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: toml in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (5.2)
# Requirement already satisfied: cachetools>=4.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (5.3.3)
# Requirement already satisfied: watchdog in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: tornado>=5.0 in ./.local/lib/python3.10/site-packages (from streamlit==1.12.0->-r requirements.txt (line 6)) (6.4)
# Requirement already satisfied: toolz in ./.local/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: jsonschema>=3.0 in ./.local/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (4.21.1)
# Requirement already satisfied: jinja2 in ./.local/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.local/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit==1.12.0->-r requirements.txt (line 6)) (4.0.11)
# Requirement already satisfied: azure-core>=1.24.0 in ./.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (1.30.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in ./.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: isodate>=0.6.0 in ./.local/lib/python3.10/site-packages (from msrest>=0.5.0->azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: regex>=2021.8.3 in ./.local/lib/python3.10/site-packages (from nltk>=3.1->textblob==0.17.1->-r requirements.txt (line 5)) (2023.12.25)
# Requirement already satisfied: joblib in ./.local/lib/python3.10/site-packages (from nltk>=3.1->textblob==0.17.1->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=0.21.0->streamlit==1.12.0->-r requirements.txt (line 6)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.21.0->streamlit==1.12.0->-r requirements.txt (line 6)) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->streamlit==1.12.0->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->language-tool-python==2.7.1->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->language-tool-python==2.7.1->-r requirements.txt (line 3)) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->language-tool-python==2.7.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.10/site-packages (from rich>=10.11.0->streamlit==1.12.0->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.local/lib/python3.10/site-packages (from rich>=10.11.0->streamlit==1.12.0->-r requirements.txt (line 6)) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.12.0->-r requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.10/site-packages (from jinja2->altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: attrs>=22.2.0 in ./.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.12.0->-r requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit==1.12.0->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-cognitiveservices-vision-computervision==0.9.0->-r requirements.txt (line 2)) (3.2.0)

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in ./.local/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.19.3 in ./.local/lib/python3.10/site-packages (from opencv-python) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in ./.local/lib/python3.10/site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.9 in ./.local/lib/python3.10/site-packages (from scikit-image) (1.12.0)
# Requirement already satisfied: pillow>=9.1 in ./.local/lib/python3.10/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: numpy>=1.23 in ./.local/lib/python3.10/site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.local/lib/python3.10/site-packages (from scikit-image) (2024.8.28)
# Requirement already satisfied: imageio>=2.33 in ./.local/lib/python3.10/site-packages (from scikit-image) (2.35.1)
# Requirement already satisfied: lazy-loader>=0.4 in ./.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: packaging>=21 in ./.local/lib/python3.10/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: networkx>=2.8 in ./.local/lib/python3.10/site-packages (from scikit-image) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-image in ./.local/lib/python3.10/site-packages (0.24.0)
# Requirement already satisfied: pillow>=9.1 in ./.local/lib/python3.10/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.local/lib/python3.10/site-packages (from scikit-image) (2024.8.28)
# Requirement already satisfied: numpy>=1.23 in ./.local/lib/python3.10/site-packages (from scikit-image) (1.24.3)
# Requirement already satisfied: lazy-loader>=0.4 in ./.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: packaging>=21 in ./.local/lib/python3.10/site-packages (from scikit-image) (23.2)
# Requirement already satisfied: networkx>=2.8 in ./.local/lib/python3.10/site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in ./.local/lib/python3.10/site-packages (from scikit-image) (2.35.1)
# Requirement already satisfied: scipy>=1.9 in ./.local/lib/python3.10/site-packages (from scikit-image) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install m2cgen
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: m2cgen in ./.local/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: numpy in ./.local/lib/python3.10/site-packages (from m2cgen) (1.24.3)

# %%
# !pip install pytesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in ./.local/lib/python3.10/site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in ./.local/lib/python3.10/site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: packaging>=21.3 in ./.local/lib/python3.10/site-packages (from pytesseract) (23.2)

# %%
# !pip install language-tool-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: language-tool-python in ./.local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: requests in ./.local/lib/python3.10/site-packages (from language-tool-python) (2.31.0)
# Requirement already satisfied: tqdm in ./.local/lib/python3.10/site-packages (from language-tool-python) (4.66.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->language-tool-python) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests->language-tool-python) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->language-tool-python) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->language-tool-python) (2020.6.20)

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in ./.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.local/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.local/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in ./.local/lib/python3.10/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import numpy as np
from scipy import ndimage as nd
from scipy import ndimage
from matplotlib import pyplot as plt
import joblib
import pressure
import zones
import feature_extraction
from skimage.feature import graycomatrix, graycoprops
from skimage.filters import gabor
from skimage.filters import gabor_kernel
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
# from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import pickle as pkl
import m2cgen
import cv2
import numpy as np
from scipy import ndimage as nd
from scipy import ndimage
from matplotlib import pyplot as plt
import joblib
import pressure
import zones
import segmentation
from skimage.feature import graycomatrix, graycoprops
from skimage.filters import gabor
from skimage.filters import gabor_kernel
from tkinter import filedialog
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import pickle as pkl
import m2cgen
from PIL import Image
import os
from textblob import TextBlob
import language_tool_python
import requests
import pandas as pd
import random
import time
import language_tool_python
import time
import pytesseract
# Out:
# 2024-09-01 18:51:40.120359: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-01 18:51:43.257549: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-01 18:51:43.261442: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-01 18:51:50.825932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !pip install Pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Pillow in ./.local/lib/python3.10/site-packages (9.2.0)

# %%
rmdir Dataset3/0/.ipynb_checkpoints

# %%
rmdir Dataset3/1/.ipynb_checkpoints

# %%
from PIL import Image
import os

def resize_and_pad_images(directory, width, height):
    """
    Resize all images in a directory to a fixed width and height,
    and pad them to ensure uniform dimensions.

    Args:
    - directory: Path to the directory containing images.
    - width: Desired width in pixels.
    - height: Desired height in pixels.
    """
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            # Open the image
            img = Image.open(filepath)

            # Resize the image
            img = img.resize((width, height), Image.ANTIALIAS)

            # Create a new image with the desired dimensions
            padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

            # Calculate the position to paste the resized image
            left = (width - img.width) // 2
            top = (height - img.height) // 2

            # Paste the resized image onto the new image
            padded_img.paste(img, (left, top))

            # Save the padded image, overwriting the original file
            padded_img.save(filepath)
            print(f"Resized and padded {filename} to {width}x{height}")
        except Exception as e:
            print(f"Failed to resize and pad {filename}: {e}")

# Define the directory path
directory = 'Dataset3_test/0'

# Define the desired width and height
target_width = 800
target_height = 300

# Resize and pad images
resize_and_pad_images(directory, target_width, target_height)
# Out:
# /tmp/ipykernel_208025/1610718653.py:21: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((width, height), Image.ANTIALIAS)
# Resized and padded 4.png to 800x300
# Resized and padded 1.png to 800x300
# Resized and padded 3.png to 800x300
# Resized and padded 2.png to 800x300

# %%
from PIL import Image
import os

def resize_and_pad_images(directory, width, height):
    """
    Resize all images in a directory to a fixed width and height,
    and pad them to ensure uniform dimensions.

    Args:
    - directory: Path to the directory containing images.
    - width: Desired width in pixels.
    - height: Desired height in pixels.
    """
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            # Open the image
            img = Image.open(filepath)

            # Resize the image
            img = img.resize((width, height), Image.ANTIALIAS)

            # Create a new image with the desired dimensions
            padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

            # Calculate the position to paste the resized image
            left = (width - img.width) // 2
            top = (height - img.height) // 2

            # Paste the resized image onto the new image
            padded_img.paste(img, (left, top))

            # Save the padded image, overwriting the original file
            padded_img.save(filepath)
            print(f"Resized and padded {filename} to {width}x{height}")
        except Exception as e:
            print(f"Failed to resize and pad {filename}: {e}")

# Define the directory path
directory = 'Dataset3/0'

# Define the desired width and height
target_width = 800
target_height = 300

# Resize and pad images
resize_and_pad_images(directory, target_width, target_height)
# Out:
# /tmp/ipykernel_208025/1675459703.py:21: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((width, height), Image.ANTIALIAS)
# Resized and padded 10.png to 800x300
# Resized and padded 23.png to 800x300
# Resized and padded 17.png to 800x300
# Resized and padded 48.png to 800x300
# Resized and padded 8.png to 800x300
# Resized and padded 31.png to 800x300
# Resized and padded 45.png to 800x300
# Resized and padded 43.png to 800x300
# Resized and padded 44.png to 800x300
# Resized and padded 5.png to 800x300
# Resized and padded 30.png to 800x300
# Resized and padded 6.png to 800x300
# Resized and padded 27.png to 800x300
# Resized and padded 26.png to 800x300
# Resized and padded 36.png to 800x300
# Resized and padded 34.png to 800x300
# Resized and padded 29.png to 800x300
# Resized and padded 32.png to 800x300
# Resized and padded 16.png to 800x300
# Resized and padded 46.png to 800x300
# Resized and padded 37.png to 800x300
# Resized and padded 42.png to 800x300
# Resized and padded 14.png to 800x300
# Resized and padded 7.png to 800x300
# Resized and padded 39.png to 800x300
# Resized and padded 22.png to 800x300
# Resized and padded 21.png to 800x300
# Resized and padded 50.png to 800x300
# Resized and padded 12.png to 800x300
# Resized and padded 15.png to 800x300
# Resized and padded 41.png to 800x300
# Resized and padded 20.png to 800x300
# Resized and padded 25.png to 800x300
# Resized and padded 40.png to 800x300
# Resized and padded 19.png to 800x300
# Resized and padded 38.png to 800x300
# Resized and padded 18.png to 800x300
# Resized and padded 35.png to 800x300
# Resized and padded 11.png to 800x300
# Resized and padded 9.png to 800x300
# Resized and padded 33.png to 800x300
# Resized and padded 13.png to 800x300
# Resized and padded 47.png to 800x300
# Resized and padded 49.png to 800x300
# Resized and padded 28.png to 800x300
# Resized and padded 24.png to 800x300

# %%
from PIL import Image
import os

def resize_and_pad_images(directory, width, height):
    """
    Resize all images in a directory to a fixed width and height,
    and pad them to ensure uniform dimensions.

    Args:
    - directory: Path to the directory containing images.
    - width: Desired width in pixels.
    - height: Desired height in pixels.
    """
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            # Open the image
            img = Image.open(filepath)

            # Resize the image
            img = img.resize((width, height), Image.ANTIALIAS)

            # Create a new image with the desired dimensions
            padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

            # Calculate the position to paste the resized image
            left = (width - img.width) // 2
            top = (height - img.height) // 2

            # Paste the resized image onto the new image
            padded_img.paste(img, (left, top))

            # Save the padded image, overwriting the original file
            padded_img.save(filepath)
            print(f"Resized and padded {filename} to {width}x{height}")
        except Exception as e:
            print(f"Failed to resize and pad {filename}: {e}")

# Define the directory path
directory = 'Dataset3_test/1'

# Define the desired width and height
target_width = 800
target_height = 300

# Resize and pad images
resize_and_pad_images(directory, target_width, target_height)
# Out:
# Resized and padded 4.png to 800x300
# Resized and padded 1.png to 800x300
# Resized and padded 3.png to 800x300
# Resized and padded 2.png to 800x300
# /tmp/ipykernel_208025/3409834789.py:21: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((width, height), Image.ANTIALIAS)

# %%
from PIL import Image
import os

def resize_and_pad_images(directory, width, height):
    """
    Resize all images in a directory to a fixed width and height,
    and pad them to ensure uniform dimensions.

    Args:
    - directory: Path to the directory containing images.
    - width: Desired width in pixels.
    - height: Desired height in pixels.
    """
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            # Open the image
            img = Image.open(filepath)

            # Resize the image
            img = img.resize((width, height), Image.ANTIALIAS)

            # Create a new image with the desired dimensions
            padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

            # Calculate the position to paste the resized image
            left = (width - img.width) // 2
            top = (height - img.height) // 2

            # Paste the resized image onto the new image
            padded_img.paste(img, (left, top))

            # Save the padded image, overwriting the original file
            padded_img.save(filepath)
            print(f"Resized and padded {filename} to {width}x{height}")
        except Exception as e:
            print(f"Failed to resize and pad {filename}: {e}")

# Define the directory path
directory = 'Dataset3/1'

# Define the desired width and height
target_width = 800
target_height = 300

# Resize and pad images
resize_and_pad_images(directory, target_width, target_height)
# Out:
# /tmp/ipykernel_208025/2875173598.py:21: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((width, height), Image.ANTIALIAS)
# Resized and padded 10.png to 800x300
# Resized and padded 23.png to 800x300
# Resized and padded 17.png to 800x300
# Resized and padded 48.png to 800x300
# Resized and padded 8.png to 800x300
# Resized and padded 31.png to 800x300
# Resized and padded 45.png to 800x300
# Resized and padded 43.png to 800x300
# Resized and padded 44.png to 800x300
# Resized and padded 5.png to 800x300
# Resized and padded 30.png to 800x300
# Resized and padded 6.png to 800x300
# Resized and padded 27.png to 800x300
# Resized and padded 26.png to 800x300
# Resized and padded 36.png to 800x300
# Resized and padded 34.png to 800x300
# Resized and padded 29.png to 800x300
# Resized and padded 32.png to 800x300
# Resized and padded 16.png to 800x300
# Resized and padded 46.png to 800x300
# Resized and padded 37.png to 800x300
# Resized and padded 42.png to 800x300
# Resized and padded 14.png to 800x300
# Resized and padded 7.png to 800x300
# Resized and padded 39.png to 800x300
# Resized and padded 22.png to 800x300
# Resized and padded 21.png to 800x300
# Resized and padded 50.png to 800x300
# Resized and padded 12.png to 800x300
# Resized and padded 15.png to 800x300
# Resized and padded 41.png to 800x300
# Resized and padded 20.png to 800x300
# Resized and padded 25.png to 800x300
# Resized and padded 40.png to 800x300
# Resized and padded 19.png to 800x300
# Resized and padded 38.png to 800x300
# Resized and padded 18.png to 800x300
# Resized and padded 35.png to 800x300
# Resized and padded 11.png to 800x300
# Resized and padded 9.png to 800x300
# Resized and padded 33.png to 800x300
# Resized and padded 13.png to 800x300
# Resized and padded 47.png to 800x300
# Resized and padded 49.png to 800x300
# Resized and padded 28.png to 800x300
# Resized and padded 24.png to 800x300

# %%
ANN_DATA1=[]
S_Data=[]
S_label=[]
cnt=0
cw_directory = os.getcwd()
H_dataset = 'Dataset3'
for filename in os.listdir(H_dataset):
    sub_dir=(H_dataset+'/' +filename)
    for img_name in os.listdir(sub_dir):
        img_dir=str(sub_dir+ '/' +img_name)
        print(img_dir)
        feature_matrix1 = feature_extraction.Feature_extraction(img_dir)
        #print(len(feature_matrix1))
        S_Data.append(feature_matrix1)
        S_label.append(int(filename))
    cnt+=1
    print(cnt)
# Out:
# Dataset3/1/10.png
# Dataset3/1/23.png
# Dataset3/1/17.png
# Dataset3/1/48.png
# Dataset3/1/8.png
# Dataset3/1/31.png
# Dataset3/1/45.png
# Dataset3/1/43.png
# Dataset3/1/44.png
# Dataset3/1/5.png
# Dataset3/1/30.png
# Dataset3/1/6.png
# Dataset3/1/27.png
# Dataset3/1/26.png
# Dataset3/1/36.png
# Dataset3/1/34.png
# Dataset3/1/29.png
# Dataset3/1/32.png
# Dataset3/1/16.png
# Dataset3/1/46.png
# Dataset3/1/37.png
# Dataset3/1/42.png
# Dataset3/1/14.png
# Dataset3/1/7.png
# Dataset3/1/39.png
# Dataset3/1/22.png
# Dataset3/1/21.png
# Dataset3/1/50.png
# Dataset3/1/12.png
# Dataset3/1/15.png
# Dataset3/1/41.png
# Dataset3/1/20.png
# Dataset3/1/25.png
# Dataset3/1/40.png
# Dataset3/1/19.png
# Dataset3/1/38.png
# Dataset3/1/18.png
# Dataset3/1/35.png
# Dataset3/1/11.png
# Dataset3/1/9.png
# Dataset3/1/33.png
# Dataset3/1/13.png
# Dataset3/1/47.png
# Dataset3/1/49.png
# Dataset3/1/28.png
# Dataset3/1/24.png
# 1
# Dataset3/0/10.png
# Dataset3/0/23.png
# Dataset3/0/17.png
# Dataset3/0/48.png
# Dataset3/0/8.png
# Dataset3/0/31.png
# Dataset3/0/45.png
# Dataset3/0/43.png
# Dataset3/0/44.png
# Dataset3/0/5.png
# Dataset3/0/30.png
# Dataset3/0/6.png
# Dataset3/0/27.png
# Dataset3/0/26.png
# Dataset3/0/36.png
# Dataset3/0/34.png
# Dataset3/0/29.png
# Dataset3/0/32.png
# Dataset3/0/16.png
# Dataset3/0/46.png
# Dataset3/0/37.png
# Dataset3/0/42.png
# Dataset3/0/14.png
# Dataset3/0/7.png
# Dataset3/0/39.png
# Dataset3/0/22.png
# Dataset3/0/21.png
# Dataset3/0/50.png
# Dataset3/0/12.png
# Dataset3/0/15.png
# Dataset3/0/41.png
# Dataset3/0/20.png
# Dataset3/0/25.png
# Dataset3/0/40.png
# Dataset3/0/19.png
# Dataset3/0/38.png
# Dataset3/0/18.png
# Dataset3/0/35.png
# Dataset3/0/11.png
# Dataset3/0/9.png
# Dataset3/0/33.png
# Dataset3/0/13.png
# Dataset3/0/47.png
# Dataset3/0/49.png
# Dataset3/0/28.png
# Dataset3/0/24.png
# 2
# 3

# %%
ANN_DATA1=[]
S_Data_test=[]
S_label_test=[]
cnt=0
cw_directory = os.getcwd()
H_dataset = 'Dataset3_test'
for filename in os.listdir(H_dataset):
    sub_dir=(H_dataset+'/' +filename)
    for img_name in os.listdir(sub_dir):
        img_dir=str(sub_dir+ '/' +img_name)
        print(img_dir)
        feature_matrix1 = feature_extraction.Feature_extraction(img_dir)
        #print(len(feature_matrix1))
        S_Data_test.append(feature_matrix1)
        S_label_test.append(int(filename))
    cnt+=1
    print(cnt)
# Out:
# Dataset3_test/1/4.png
# Dataset3_test/1/1.png
# Dataset3_test/1/3.png
# Dataset3_test/1/2.png
# 1
# Dataset3_test/0/4.png
# Dataset3_test/0/1.png
# Dataset3_test/0/3.png
# Dataset3_test/0/2.png
# 2
# 3

# %%
train_data = pd.read_csv("train .csv")
test_data = pd.read_csv("test.csv")
# train_data.drop(columns=["percentage_of_phonetic_accuraccy"], inplace=True)
# test_data.drop(columns=["percentage_of_phonetic_accuraccy"], inplace=True)
x_train = train_data.drop(["presence_of_dyslexia"], axis= "columns")
x_test = test_data.drop(["presence_of_dyslexia"], axis= "columns")
y_train = train_data.presence_of_dyslexia
y_test = test_data.presence_of_dyslexia
x_test.head()
# Out:
#    spelling_accuracy  gramatical_accuracy  percentage_of_corrections
# 0          99.159664            99.720670                   8.108108
# 1          98.259188            99.806576                   5.263158
# 2          98.989899            99.326599                   8.064516
# 3          97.891566            99.395770                   3.076923
# 4          98.087432            99.724518                   7.692308

# %% [markdown]
# Training a Logistic regression Model

# %%
model_logistic = LogisticRegression()
model_logistic.fit(x_train, y_train)
print(model_logistic.score(x_test, y_test))
print(model_logistic.score(x_train,y_train))
sns.heatmap(confusion_matrix(model_logistic.predict(x_test), y_test), annot=True)
# Out:
# 0.85
# 0.975
# <Axes: >

# %%
# sns.heatmap(confusion_matrix(model_logistic.predict(x_train), y_train), annot=True)

# %% [markdown]
# Training a Decision Tree classifier

# %%
model_DT = DecisionTreeClassifier()
model_DT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_tree=(model_DT.score(x_test, y_test))
print(decision_tree)
print(model_DT.score(x_train, y_train))
# Out:
# 0.95
# 1.0

# %%
# sns.heatmap(confusion_matrix(model_DT.predict(x_test), y_test), annot=True)

# %%
# sns.heatmap(confusion_matrix(model_DT.predict(x_train), y_train), annot=True)

# %%
model_svc_linear = SVC(kernel = 'linear',gamma = 'scale', shrinking = False,)
model_svc_linear.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', shrinking=False)

# %%
img_text_mod_acc=(model_svc_linear.score(x_test, y_test))
print(img_text_mod_acc)
# print(model_svc_linear.score(x_train, y_train))
# Out:
# 0.85

# %%
pkl.dump(model_svc_linear, open("SVC_img_text.sav", 'wb'))

# %%
## MLP Training
model1 = MLPClassifier(activation='relu', verbose=True,
                                       hidden_layer_sizes=(200,), batch_size=40)
model1=model1.fit(np.array(S_Data), np.array(S_label))
ypred_MLP = model1.predict(np.array(S_Data))

# plot_confusion_matrix(model1, np.array(S_Data), np.array(S_label))
plt.show()
S_ACC=accuracy_score(S_label,ypred_MLP)

print("Training ANN accuracy is",accuracy_score(S_label,ypred_MLP))
joblib.dump(model1, "Trained_H_Model.pkl")
# Out:
# Iteration 1, loss = 18.02191634
# Iteration 2, loss = 16.52835732
# Iteration 3, loss = 18.02191401
# Iteration 4, loss = 18.02191275
# Iteration 5, loss = 15.58066780
# Iteration 6, loss = 11.85242380
# Iteration 7, loss = 9.18597622
# Iteration 8, loss = 6.88410300
# Iteration 9, loss = 3.22504529
# Iteration 10, loss = 5.37481190
# Iteration 11, loss = 2.70932441
# Iteration 12, loss = 5.10231695
# Iteration 13, loss = 2.82552901
# Iteration 14, loss = 3.62911245
# Iteration 15, loss = 2.44946896
# Iteration 16, loss = 2.75335867
# Iteration 17, loss = 1.72596890
# Iteration 18, loss = 1.80849827
# Iteration 19, loss = 1.57168417
# Iteration 20, loss = 1.53260527
# Iteration 21, loss = 1.37699437
# Iteration 22, loss = 1.37237222
# Iteration 23, loss = 1.25763874
# Iteration 24, loss = 1.22325222
# Iteration 25, loss = 1.26812738
# Iteration 26, loss = 1.02484308
# Iteration 27, loss = 1.00519457
# Iteration 28, loss = 0.92677378
# Iteration 29, loss = 0.92781497
# Iteration 30, loss = 0.79399453
# Iteration 31, loss = 0.74659605
# Iteration 32, loss = 0.86493264
# Iteration 33, loss = 0.61461938
# Iteration 34, loss = 0.62901039
# Iteration 35, loss = 0.82394762
# Iteration 36, loss = 1.01307759
# Iteration 37, loss = 0.57858493
# Iteration 38, loss = 0.54012287
# Iteration 39, loss = 0.47494816
# Iteration 40, loss = 0.50238404
# Iteration 41, loss = 0.60696289
# Iteration 42, loss = 0.61612612
# Iteration 43, loss = 0.48458025
# Iteration 44, loss = 0.36370214
# Iteration 45, loss = 0.37394530
# Iteration 46, loss = 0.46414578
# Iteration 47, loss = 0.23910879
# Iteration 48, loss = 0.28606310
# Iteration 49, loss = 0.73572837
# Iteration 50, loss = 0.60969263
# Iteration 51, loss = 0.63619250
# Iteration 52, loss = 0.32977543
# Iteration 53, loss = 0.24616561
# Iteration 54, loss = 0.21680035
# Iteration 55, loss = 0.36373091
# Iteration 56, loss = 0.40880913
# Iteration 57, loss = 0.28527292
# Iteration 58, loss = 0.76039699
# Iteration 59, loss = 0.50087640
# Iteration 60, loss = 0.59200374
# Iteration 61, loss = 0.30403234
# Iteration 62, loss = 0.70029193
# Iteration 63, loss = 1.95695066
# Iteration 64, loss = 0.28027236
# Iteration 65, loss = 0.36633478
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training ANN accuracy is 0.9130434782608695
# ['Trained_H_Model.pkl']

# %%
model_DT = DecisionTreeClassifier()
model_DT.fit(S_Data, S_label)
# Out:
# DecisionTreeClassifier()

# %%
Y_DT_pred = model_DT.predict(S_Data_test)

# Calculating the accuracy
DT_ACC = accuracy_score(Y_DT_pred, S_label_test)
print(DT_ACC)
# Out:
# 0.875

# %%
## Train SVM
from sklearn.svm import SVC
def train_SVM(featuremat,label):
    clf = SVC(kernel = 'rbf', random_state = 0)
    clf.fit(np.array(S_Data), np.array(S_label))
    y_pred = clf.predict(np.array(featuremat))
    # plot_confusion_matrix(clf, np.array(featuremat), np.array(label))
    plt.show()
    print("SVM Accuracy",accuracy_score(label,y_pred))
    return clf

svc_model1 = train_SVM(S_Data,S_label)
Y_SCM_S_pred= svc_model1.predict(S_Data)
SVM_S_ACC=accuracy_score(Y_SCM_S_pred,S_label)


plt.figure()
plt.bar(['ANN'],[S_ACC], label="ANN Accuracy", color='r')

# plt.bar(['Img_txt'],[img_text_mod_acc], label="Image_to_text Accuracy", color='b')
plt.bar(['SVM'],[img_text_mod_acc], label="SVM Accuracy", color='g')

plt.bar(['Decision_tree'],[DT_ACC], label="DTree Accuracy", color='b')

# Annotating the bars with the accuracy values
plt.text(0, S_ACC + 0.01, f'{S_ACC:.2f}', ha='center', color='r')
plt.text(1, img_text_mod_acc + 0.01, f'{img_text_mod_acc:.2f}', ha='center', color='g')
plt.text(2, DT_ACC + 0.01, f'{DT_ACC:.2f}', ha='center', color='g')

plt.legend()
plt.ylabel('Accuracy')
plt.show()
# Out:
# SVM Accuracy 0.717391304347826

# %%
def compute_feats(image, kernels):
    feats = np.zeros((len(kernels), 2), dtype=np.double)
    for k, kernel in enumerate(kernels):
        filtered = nd.convolve(image, kernel, mode='wrap')
        feats[k, 0] = filtered.mean()
        feats[k, 1] = filtered.var()
    return feats

def GLCM_Feature(cropped):
    # GLCM Feature extraction
    glcm = graycomatrix(cropped, [1, 2], [0, np.pi/2], levels=256, normed=True, symmetric=True)
    dissim = (graycoprops(glcm, 'dissimilarity'))
    dissim=np.reshape(dissim, dissim.size)
    correl = (graycoprops(glcm, 'correlation'))
    correl=np.reshape(correl,correl.size)
    energy = (graycoprops(glcm, 'energy'))
    energy=np.reshape(energy,energy.size)
    contrast= (graycoprops(glcm, 'contrast'))
    contrast= np.reshape(contrast,contrast.size)
    homogen= (graycoprops(glcm, 'homogeneity'))
    homogen = np.reshape(homogen,homogen.size)
    asm =(graycoprops(glcm, 'ASM'))
    asm = np.reshape(asm,asm.size)
    glcm = glcm.flatten()
    Mn=sum(glcm)
    Glcm_feature = np.concatenate((dissim,correl,energy,contrast,homogen,asm,Mn),axis=None)
    return Glcm_feature

# %%
# from PIL import Image
# import os

# def resize_and_pad_images(directory, width, height):
#     """
#     Resize all images in a directory to a fixed width and height,
#     and pad them to ensure uniform dimensions.

#     Args:
#     - directory: Path to the directory containing images.
#     - width: Desired width in pixels.
#     - height: Desired height in pixels.
#     """
#     for filename in os.listdir(directory):
#         filepath = os.path.join(directory, filename)
#         try:
#             # Open the image
#             img = Image.open(filepath)

#             # Resize the image
#             img = img.resize((width, height), Image.ANTIALIAS)

#             # Create a new image with the desired dimensions
#             padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

#             # Calculate the position to paste the resized image
#             left = (width - img.width) // 2
#             top = (height - img.height) // 2

#             # Paste the resized image onto the new image
#             padded_img.paste(img, (left, top))

#             # Save the padded image, overwriting the original file
#             padded_img.save(filepath)
#             print(f"Resized and padded {filename} to {width}x{height}")
#         except Exception as e:
#             print(f"Failed to resize and pad {filename}: {e}")

# # Define the directory path
# directory = '/content/akshat_non_dys.png'

# # Define the desired width and height
# target_width = 300
# target_height = 200

# # Resize and pad images
# resize_and_pad_images(directory, target_width, target_height)

# %%
from PIL import Image
import os

def resize_and_pad_images(directory, width, height):
    """
    Resize all images in a directory to a fixed width and height,
    and pad them to ensure uniform dimensions.

    Args:
    - directory: Path to the directory containing images.
    - width: Desired width in pixels.
    - height: Desired height in pixels.
    """
    filepath = '45.png'
    try:
        # Open the image
        img = Image.open(filepath)

        # Resize the image
        img = img.resize((width, height), Image.ANTIALIAS)

        # Create a new image with the desired dimensions
        padded_img = Image.new("RGB", (width, height), color=(255, 255, 255))  # White background

        # Calculate the position to paste the resized image
        left = (width - img.width) // 2
        top = (height - img.height) // 2

        # Paste the resized image onto the new image
        padded_img.paste(img, (left, top))

        # Save the padded image, overwriting the original file
        padded_img.save(filepath)
        print(f"Resized and padded {filename} to {width}x{height}")
    except Exception as e:
        print(f"Failed to resize and pad {filename}: {e}")


# Define the desired width and height
target_width = 800
target_height = 300

# Resize and pad images
resize_and_pad_images(directory, target_width, target_height)
# Out:
# Resized and padded .ipynb_checkpoints to 800x300
# /tmp/ipykernel_122093/4274493291.py:20: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((width, height), Image.ANTIALIAS)

# %%
list1= ['strong personality', 'moderate personality' , 'weak personality']

    #Read Image
# S_filename = filedialog.askopenfilename(title='Select Signature Image')
S_img = cv2.imread('45.png')

if len(S_img.shape) == 3:
    G_img = cv2.cvtColor(S_img, cv2.COLOR_RGB2GRAY)
else:
    G_img=S_img.copy()

# cv2_imshow(G_img)
# cv2.waitKey(0)
plt.imshow(G_img)
plt.axis('off')  # Hide axes
plt.show()

# %%
#Gaussian Filter and thresholding image
blur_radius = 2
blurred_image = ndimage.gaussian_filter(G_img, blur_radius)
threshold, binarized_image = cv2.threshold(blurred_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# cv2_imshow('Segmented Image',binarized_image)
# cv2_imshow(binarized_image)
# cv2.waitKey(0)
plt.imshow(binarized_image)
plt.axis('off')  # Hide axes
plt.show()
    # Find the center of mass
r, c = np.where(binarized_image == 0)
r_center = int(r.mean() - r.min())
c_center = int(c.mean() - c.min())

    # Crop the image with a tight box
cropped = G_img[r.min(): r.max(), c.min(): c.max()]

# %%
## Signature Feature extraction
Average,Percentage = pressure.pressure(cropped)
top, middle, bottom = zones.findZone(cropped)

Glcm_feature_signature =GLCM_Feature(cropped)
Glcm_feature_signature=Glcm_feature_signature.flatten()

bw_img,angle1= segmentation.Segmentation(G_img)

feature_matrix1 = np.concatenate((Average,Percentage,angle1,top, middle, bottom,Glcm_feature_signature),axis=None)

Model_lod1 = joblib.load("Trained_H_Model.pkl")

#ypred = Model_lod.predict(cv2.transpose(Feature_matrix))
pred=Model_lod1.predict(cv2.transpose(feature_matrix1))
if(pred==0):
  print("\033[1;31;40m The person is DYSLEXIC")
else:
  print("\033[1;32;40m The person is NON-DYSLEXIC")
print(pred)
# Out:
#  The person is DYSLEXIC
# [0]

# %%
# Install java in cmd
# sudo apt-get update
# sudo apt-get install default-jre

# %%
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            # j+1 instead of j since previous_row and current_row are one character longer
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]


my_tool = language_tool_python.LanguageTool('en-US')

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''


def image_to_text(path):
    if not os.path.isfile(path):
        raise ValueError("The provided path does not point to a valid file.")

    try:
        # Use pytesseract to perform OCR
        extracted_text = pytesseract.image_to_string(path)
        return extracted_text
    except TesseractError as e:
        print("Error during OCR:", e)
        return None

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''

# method for finding the spelling accuracy


def spelling_accuracy(extracted_text):
    spell_corrected = TextBlob(extracted_text).correct()
    return ((len(extracted_text) - (levenshtein(extracted_text, spell_corrected)))/(len(extracted_text)+1))*100

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''

# method for gramatical accuracy


def gramatical_accuracy(extracted_text):
    spell_corrected = TextBlob(extracted_text).correct()
    correct_text = my_tool.correct(spell_corrected)
    extracted_text_set = set(spell_corrected.split(" "))
    correct_text_set = set(correct_text.split(" "))
    n = max(len(extracted_text_set - correct_text_set),
            len(correct_text_set - extracted_text_set))
    return ((len(spell_corrected) - n)/(len(spell_corrected)+1))*100

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''

# percentage of corrections

def percentage_of_corrections(extracted_text):
    tool = language_tool_python.LanguageTool('en-US')
    matches = tool.check(extracted_text)

    # Check if extracted_text is empty or contains no words
    if len(extracted_text.split()) == 0:
        return 0.0

    # Calculate the percentage of corrections based on the number of matches
    correction_percentage = (len(matches) / len(extracted_text.split())) * 100
    return correction_percentage


# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''


def get_feature_array(path: str):
    feature_array = []
    extracted_text = image_to_text(path)
    if extracted_text is not None:
        feature_array.append(spelling_accuracy(extracted_text))
        feature_array.append(gramatical_accuracy(extracted_text))
        feature_array.append(percentage_of_corrections(extracted_text))
        #feature_array.append(percentage_of_phonetic_accuraccy(extracted_text))
    return feature_array

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''

def generate_csv(folder: str, label: int, csv_name: str):
    arr = []
    for image in os.listdir(folder):
        path = os.path.join(folder, image)
        if not os.path.isfile(path):
          break
        feature_array = get_feature_array(path)
        feature_array.append(label)
        arr.append(feature_array)
        print(feature_array)
    print(arr)
    # Create the DataFrame
    df = pd.DataFrame(arr, columns=["spelling_accuracy", "gramatical_accuracy", "percentage_of_corrections",
                                     "presence_of_dyslexia"])
    # Save to CSV using the provided csv_name
    df.to_csv(csv_name)

# '''-------------------------------------------------------------------------------------------------------------------------------------------------------------------------'''


def score(input):
    if input[0] <= 96.40350723266602:
        var0 = [0.0, 1.0]
    else:
        if input[1] <= 99.1046028137207:
            var0 = [0.0, 1.0]
        else:
            if input[2] <= 2.408450722694397:
                if input[2] <= 1.7936508059501648:
                    var0 = [1.0, 0.0]
                else:
                    var0 = [0.0, 1.0]
            else:
                var0 = [1.0, 0.0]
    return var0

# %%
import os

# Define the paths to the dyslexia and non-dyslexia folders
dyslexia_folder = 'Dyslexia'
non_dyslexia_folder = 'Non-dyslexia'


# generate_csv(dyslexia_folder, 1, 'test.csv')
generate_csv(non_dyslexia_folder, 0, 'test_new.csv')
# Out:
# [85.18518518518519, 99.70674486803519, 53.62318840579711, 0]
# [93.80952380952381, 99.75961538461539, 35.38461538461539, 0]
# [92.02733485193622, 99.76851851851852, 41.0958904109589, 0]
# [91.14285714285715, 99.71014492753623, 35.0, 0]
# [[85.18518518518519, 99.70674486803519, 53.62318840579711, 0], [93.80952380952381, 99.75961538461539, 35.38461538461539, 0], [92.02733485193622, 99.76851851851852, 41.0958904109589, 0], [91.14285714285715, 99.71014492753623, 35.0, 0]]

# %%
test_data = pd.read_csv("test_new.csv")
test_data.drop(columns=["Unnamed: 0"], inplace=True)
x_test_new = test_data.drop(["presence_of_dyslexia"], axis= "columns")
y_test_new = test_data.presence_of_dyslexia
x_test_new.head()
# Out:
#    spelling_accuracy  gramatical_accuracy  percentage_of_corrections
# 0          85.185185            99.706745                  53.623188
# 1          93.809524            99.759615                  35.384615
# 2          92.027335            99.768519                  41.095890
# 3          91.142857            99.710145                  35.000000

# %%
# Load the model
loaded_model = pkl.load(open("SVC_img_text.sav", 'rb'))

predictions = loaded_model.predict(x_test_new)
# If you want to compare predictions with true labels, you can print them side by side
for i in range(len(predictions)):
  if(predictions[i] == 1):
    print("\033[1;31;40m The person is DYSLEXIC")
  else:
    print("\033[1;32;40m The person is NON-DYSLEXIC")
# Out:
#  The person is DYSLEXIC
#  The person is DYSLEXIC
#  The person is DYSLEXIC
#  The person is DYSLEXIC

# %% [markdown]
# end!!
